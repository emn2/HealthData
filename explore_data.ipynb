# %%
import pandas as pd
import xml.etree.ElementTree as ET
import datetime
import matplotlib.pyplot as plt

# %%
# Load the XML file
tree = ET.parse('apple_health_export/exportar.xml')

# Get the root element
root = tree.getroot()
records = []

# Iterate through elements in the XML
for child in root:
    # Check if the element is a Record
    if child.tag == 'Record':
        # Collect attributes of the Record element
        record_data = child.attrib
        # Also collect data from MetadataEntry children if needed
        metadata_entries = {}
        for subchild in child:
            if subchild.tag == 'MetadataEntry':
                key = subchild.attrib.get('key')
                value = subchild.attrib.get('value')
                metadata_entries[key] = value
        # Combine Record attributes and MetadataEntry data
        record_data.update(metadata_entries)
        # Add the combined data to the records list
        records.append(record_data)

# Convert the list of records to a DataFrame
df_records = pd.DataFrame(records)

# shorter observation names: use vectorized replace function
df_records['type'] = df_records['type'].str.replace('HKQuantityTypeIdentifier', '')
df_records['type'] = df_records['type'].str.replace('HKCategoryTypeIdentifier', '')

# Save the DataFrame to a CSV file
df_records.to_csv('apple_health_records.csv', index=False)

print("CSV file has been created.")
# Out:
# CSV file has been created.

# %%
tree = ET.parse('apple_health_export/exportar.xml')

# for every health record, extract the attributes into a dictionary (columns). Then create a list (rows).
root = tree.getroot()
record_list = [x.attrib for x in root.iter('Record')]

# create DataFrame from a list (rows) of dictionaries (columns)
data = pd.DataFrame(record_list)

# proper type to dates
for col in ['creationDate', 'startDate', 'endDate']:
    data[col] = pd.to_datetime(data[col])

# value is numeric, NaN if fails 
# comment out this to detailed stages
data['value'] = pd.to_numeric(data['value'], errors='coerce')

# some records do not measure anything, just count occurrences
# filling with 1.0 (= one time) makes it easier to aggregate
data['value'] = data['value'].fillna(1.0) #comment out this to detailed stages

# shorter observation names: use vectorized replace function
data['type'] = data['type'].str.replace('HKQuantityTypeIdentifier', '')
data['type'] = data['type'].str.replace('HKCategoryTypeIdentifier', '')

# save into CSV as this is a universally compatible data format
data.to_csv("apple_export.csv", index=False)

# %%
sleep_data = data[data['type'] == "SleepAnalysis"]
sleep_data = sleep_data[sleep_data['sourceName'] == "Apple Watch de Edson"]

display(sleep_data)
# Out:
#                   type            sourceName sourceVersion unit  \
# 1313427  SleepAnalysis  Apple Watch de Edson          10.4  NaN
# 1313428  SleepAnalysis  Apple Watch de Edson          10.4  NaN
# 1313429  SleepAnalysis  Apple Watch de Edson          10.4  NaN
# 1313430  SleepAnalysis  Apple Watch de Edson          10.4  NaN
# 1313431  SleepAnalysis  Apple Watch de Edson          10.4  NaN
# ...                ...                   ...           ...  ...
# 1318041  SleepAnalysis  Apple Watch de Edson          10.5  NaN
# 1318042  SleepAnalysis  Apple Watch de Edson          10.5  NaN
# 1318043  SleepAnalysis  Apple Watch de Edson          10.5  NaN
# 1318044  SleepAnalysis  Apple Watch de Edson          10.5  NaN
# 1318045  SleepAnalysis  Apple Watch de Edson          10.5  NaN
#
#                      creationDate                 startDate  \
# 1313427 2024-04-28 07:03:19-03:00 2024-04-27 23:37:45-03:00
# 1313428 2024-04-28 07:03:19-03:00 2024-04-27 23:51:15-03:00
# 1313429 2024-04-28 07:03:19-03:00 2024-04-28 00:13:15-03:00
# 1313430 2024-04-28 07:03:19-03:00 2024-04-28 00:21:15-03:00
# 1313431 2024-04-28 07:03:19-03:00 2024-04-27 23:37:45-03:00
# ...                           ...                       ...
# 1318041 2024-08-15 10:37:32-03:00 2024-08-15 08:16:29-03:00
# 1318042 2024-08-15 10:37:32-03:00 2024-08-15 08:21:59-03:00
# 1318043 2024-08-15 10:37:32-03:00 2024-08-15 08:52:29-03:00
# 1318044 2024-08-15 10:37:32-03:00 2024-08-15 09:23:59-03:00
# 1318045 2024-08-15 10:37:32-03:00 2024-08-15 08:21:59-03:00
#
#                           endDate  value device
# 1313427 2024-04-27 23:51:15-03:00    1.0    NaN
# 1313428 2024-04-28 00:13:15-03:00    1.0    NaN
# 1313429 2024-04-28 00:21:15-03:00    1.0    NaN
# 1313430 2024-04-28 00:30:45-03:00    1.0    NaN
# 1313431 2024-04-28 00:30:45-03:00    1.0    NaN
# ...                           ...    ...    ...
# 1318041 2024-08-15 08:21:59-03:00    1.0    NaN
# 1318042 2024-08-15 08:52:29-03:00    1.0    NaN
# 1318043 2024-08-15 09:23:59-03:00    1.0    NaN
# 1318044 2024-08-15 09:54:59-03:00    1.0    NaN
# 1318045 2024-08-15 09:54:59-03:00    1.0    NaN
#
# [4618 rows x 9 columns]

# %%
# calulate time between date(s)
sleep_data['time_asleep'] = sleep_data['endDate'] - sleep_data['startDate']

# records are grouped by creation date, so lets used that to sum up the values we need here
# total time asleep as a sum of the asleep time
# awake and bed times are max's and min's
# sleep count is the number of times the Apple Watch detected movement
# rem is the number of sleep cycles over 90 minutes (divded by 90 if they were longer than 1 cycle)
sleep_data = sleep_data.groupby('creationDate').agg(total_time_asleep=('time_asleep', 'sum'),
    bed_time=('startDate', 'min'), 
    awake_time=('endDate', 'max'), 
    sleep_counts=('creationDate','count'), 
    rem_cycles=pd.NamedAgg(column='time_asleep', aggfunc=lambda x: (x // datetime.timedelta(minutes=90)).sum()))

# Time in Bed will be different to Apple's reported figure - 
# as Apple uses the time you place your iPhone down as an additional 
# datapoint, which of course, is incorrect if you try to maintain 
# some device separation in the evenings.
# For now - we will just use Apple Watch data here
sleep_data['time_in_bed'] = sleep_data['awake_time'] - sleep_data['bed_time']
sleep_data['restless_time'] = sleep_data['time_in_bed'] - sleep_data['total_time_asleep']

# %%
# convert time duration to minutes for easier plotting and comparison
sleep_data['time_in_bed'] = (sleep_data['time_in_bed'].dt.total_seconds()/60)
sleep_data['total_time_asleep'] = (sleep_data['total_time_asleep'].dt.total_seconds()/60)

import matplotlib
matplotlib.use('TkAgg')
import matplotlib.pyplot as plt

from matplotlib.dates import DateFormatter, MonthLocator

chart1 = sleep_data[['time_in_bed','total_time_asleep']].plot(use_index=True)
plt.show()

# %%
data = pd.read_csv('apple_health_records.csv')

data = data[data['sourceName'] == "Apple Watch de Edson"]
display(data)
# Out:
# /tmp/ipykernel_664651/1240902334.py:1: DtypeWarning: Columns (2,7,9,11,13,15,20,21,23,25,29,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('apple_health_records.csv')
#                              type            sourceName sourceVersion  \
# 4                          Height  Apple Watch de Edson          10.4
# 12                       BodyMass  Apple Watch de Edson          10.4
# 330742                  HeartRate  Apple Watch de Edson          10.4
# 330743                  HeartRate  Apple Watch de Edson          10.4
# 330744                  HeartRate  Apple Watch de Edson          10.4
# ...                           ...                   ...           ...
# 1321438  HeartRateVariabilitySDNN  Apple Watch de Edson          10.5
# 1321439  HeartRateVariabilitySDNN  Apple Watch de Edson          10.5
# 1321440  HeartRateVariabilitySDNN  Apple Watch de Edson          10.5
# 1321441  HeartRateVariabilitySDNN  Apple Watch de Edson          10.5
# 1321442  HeartRateVariabilitySDNN  Apple Watch de Edson          10.5
#
#               unit               creationDate                  startDate  \
# 4               cm  2024-04-27 23:19:57 -0300  2024-04-27 23:19:57 -0300
# 12              kg  2024-04-27 23:19:57 -0300  2024-04-27 23:19:57 -0300
# 330742   count/min  2024-04-28 08:42:18 -0300  2024-04-28 08:40:52 -0300
# 330743   count/min  2024-04-28 08:44:45 -0300  2024-04-28 08:43:43 -0300
# 330744   count/min  2024-04-28 08:47:23 -0300  2024-04-28 08:43:48 -0300
# ...            ...                        ...                        ...
# 1321438         ms  2024-08-15 07:31:56 -0300  2024-08-15 07:30:56 -0300
# 1321439         ms  2024-08-15 09:31:57 -0300  2024-08-15 09:30:56 -0300
# 1321440         ms  2024-08-15 11:32:49 -0300  2024-08-15 11:31:48 -0300
# 1321441         ms  2024-08-15 14:10:12 -0300  2024-08-15 14:09:12 -0300
# 1321442         ms  2024-08-15 15:42:41 -0300  2024-08-15 15:41:40 -0300
#
#                            endDate    value  HKWasUserEntered  \
# 4        2024-04-27 23:19:57 -0300    178.0               NaN
# 12       2024-04-27 23:19:57 -0300     79.0               NaN
# 330742   2024-04-28 08:40:52 -0300     88.0               NaN
# 330743   2024-04-28 08:43:43 -0300  84.4355               NaN
# 330744   2024-04-28 08:43:48 -0300     85.0               NaN
# ...                            ...      ...               ...
# 1321438  2024-08-15 07:31:55 -0300  29.7119               NaN
# 1321439  2024-08-15 09:31:56 -0300  67.7189               NaN
# 1321440  2024-08-15 11:32:48 -0300  79.3807               NaN
# 1321441  2024-08-15 14:10:11 -0300  42.9472               NaN
# 1321442  2024-08-15 15:42:39 -0300  53.8966               NaN
#
#                                                     device  ...  \
# 4                                                      NaN  ...
# 12                                                     NaN  ...
# 330742   <<HKDevice: 0x3016faf80>, name:Apple Watch, ma...  ...
# 330743   <<HKDevice: 0x3016faf80>, name:Apple Watch, ma...  ...
# 330744   <<HKDevice: 0x3016faf80>, name:Apple Watch, ma...  ...
# ...                                                    ...  ...
# 1321438  <<HKDevice: 0x3015745a0>, name:Apple Watch, ma...  ...
# 1321439  <<HKDevice: 0x3015745a0>, name:Apple Watch, ma...  ...
# 1321440  <<HKDevice: 0x3015745a0>, name:Apple Watch, ma...  ...
# 1321441  <<HKDevice: 0x3015745a0>, name:Apple Watch, ma...  ...
# 1321442  <<HKDevice: 0x3015745a0>, name:Apple Watch, ma...  ...
#
#          HKMetadataKeyHeartRateRecoveryActivityDuration  \
# 4                                                   NaN
# 12                                                  NaN
# 330742                                              NaN
# 330743                                              NaN
# 330744                                              NaN
# ...                                                 ...
# 1321438                                             NaN
# 1321439                                             NaN
# 1321440                                             NaN
# 1321441                                             NaN
# 1321442                                             NaN
#
#         HKMetadataKeyHeartRateRecoveryTestType  \
# 4                                          NaN
# 12                                         NaN
# 330742                                     NaN
# 330743                                     NaN
# 330744                                     NaN
# ...                                        ...
# 1321438                                    NaN
# 1321439                                    NaN
# 1321440                                    NaN
# 1321441                                    NaN
# 1321442                                    NaN
#
#          HKMetadataKeyHeartRateRecoveryMaxObservedRecoveryHeartRate  \
# 4                                                      NaN
# 12                                                     NaN
# 330742                                                 NaN
# 330743                                                 NaN
# 330744                                                 NaN
# ...                                                    ...
# 1321438                                                NaN
# 1321439                                                NaN
# 1321440                                                NaN
# 1321441                                                NaN
# 1321442                                                NaN
#
#         HKMetadataKeyHeartRateRecoveryActivityType  \
# 4                                              NaN
# 12                                             NaN
# 330742                                         NaN
# 330743                                         NaN
# 330744                                         NaN
# ...                                            ...
# 1321438                                        NaN
# 1321439                                        NaN
# 1321440                                        NaN
# 1321441                                        NaN
# 1321442                                        NaN
#
#          HKMetadataKeyMaximumLightIntensity HKActivityType  \
# 4                                       NaN            NaN
# 12                                      NaN            NaN
# 330742                                  NaN            NaN
# 330743                                  NaN            NaN
# 330744                                  NaN            NaN
# ...                                     ...            ...
# 1321438                                 NaN            NaN
# 1321439                                 NaN            NaN
# 1321440                                 NaN            NaN
# 1321441                                 NaN            NaN
# 1321442                                 NaN            NaN
#
#          HKPhysicalEffortEstimationType  HKIndoorWorkout  HKTimeZone  \
# 4                                   NaN              NaN         NaN
# 12                                  NaN              NaN         NaN
# 330742                              NaN              NaN         NaN
# 330743                              NaN              NaN         NaN
# 330744                              NaN              NaN         NaN
# ...                                 ...              ...         ...
# 1321438                             NaN              NaN         NaN
# 1321439                             NaN              NaN         NaN
# 1321440                             NaN              NaN         NaN
# 1321441                             NaN              NaN         NaN
# 1321442                             NaN              NaN         NaN
#
#          HKMetadataKeyAudioExposureLevel
# 4                                    NaN
# 12                                   NaN
# 330742                               NaN
# 330743                               NaN
# 330744                               NaN
# ...                                  ...
# 1321438                              NaN
# 1321439                              NaN
# 1321440                              NaN
# 1321441                              NaN
# 1321442                              NaN
#
# [697460 rows x 31 columns]

# %%
data['type'].value_counts()
# Out:
# ActiveEnergyBurned               227248
# BasalEnergyBurned                167758
# HeartRate                        113211
# DistanceWalkingRunning            44665
# PhysicalEffort                    39439
# StepCount                         25818
# RunningSpeed                      13263
# RunningPower                      13237
# AppleExerciseTime                  7278
# RespiratoryRate                    6423
# RunningVerticalOscillation         5114
# RunningGroundContactTime           4979
# SleepAnalysis                      4618
# RunningStrideLength                4527
# AppleStandTime                     4445
# EnvironmentalAudioExposure         4216
# DistanceCycling                    4054
# AppleStandHour                     2353
# OxygenSaturation                   1851
# HeartRateVariabilitySDNN           1030
# TimeInDaylight                      612
# EnvironmentalSoundReduction         508
# FlightsClimbed                      174
# StairAscentSpeed                    154
# StairDescentSpeed                   121
# AppleSleepingWristTemperature       108
# RestingHeartRate                    107
# WalkingHeartRateAverage             103
# VO2Max                               19
# HeartRateRecoveryOneMinute           17
# HeadphoneAudioExposure                4
# AudioExposureEvent                    4
# BodyMass                              1
# Height                                1
# Name: type, dtype: int64

# %%
exercise_time = data[data['type'] == "AppleExerciseTime"]
display(exercise_time)


for col in exercise_time.columns:
    print(exercise_time[col].value_counts())
print(exercise_time.columns)
# Out:
#                       type            sourceName sourceVersion unit  \
# 1137791  AppleExerciseTime  Apple Watch de Edson          10.4  min
# 1137792  AppleExerciseTime  Apple Watch de Edson          10.4  min
# 1137793  AppleExerciseTime  Apple Watch de Edson          10.4  min
# 1137794  AppleExerciseTime  Apple Watch de Edson          10.4  min
# 1137795  AppleExerciseTime  Apple Watch de Edson          10.4  min
# ...                    ...                   ...           ...  ...
# 1145104  AppleExerciseTime  Apple Watch de Edson          10.5  min
# 1145105  AppleExerciseTime  Apple Watch de Edson          10.5  min
# 1145106  AppleExerciseTime  Apple Watch de Edson          10.5  min
# 1145107  AppleExerciseTime  Apple Watch de Edson          10.5  min
# 1145108  AppleExerciseTime  Apple Watch de Edson          10.5  min
#
#                       creationDate                  startDate  \
# 1137791  2024-04-28 08:53:05 -0300  2024-04-28 08:51:00 -0300
# 1137792  2024-04-28 08:55:57 -0300  2024-04-28 08:52:00 -0300
# 1137793  2024-04-28 08:55:57 -0300  2024-04-28 08:53:00 -0300
# 1137794  2024-04-28 08:58:43 -0300  2024-04-28 08:55:00 -0300
# 1137795  2024-04-28 09:02:28 -0300  2024-04-28 08:58:00 -0300
# ...                            ...                        ...
# 1145104  2024-08-15 18:45:49 -0300  2024-08-15 18:44:00 -0300
# 1145105  2024-08-15 18:47:00 -0300  2024-08-15 18:45:00 -0300
# 1145106  2024-08-15 18:47:59 -0300  2024-08-15 18:46:00 -0300
# 1145107  2024-08-15 18:48:50 -0300  2024-08-15 18:47:00 -0300
# 1145108  2024-08-15 18:49:52 -0300  2024-08-15 18:48:00 -0300
#
#                            endDate value  HKWasUserEntered  \
# 1137791  2024-04-28 08:52:00 -0300   1.0               NaN
# 1137792  2024-04-28 08:53:00 -0300   1.0               NaN
# 1137793  2024-04-28 08:54:00 -0300   1.0               NaN
# 1137794  2024-04-28 08:56:00 -0300   1.0               NaN
# 1137795  2024-04-28 08:59:00 -0300   1.0               NaN
# ...                            ...   ...               ...
# 1145104  2024-08-15 18:45:00 -0300   1.0               NaN
# 1145105  2024-08-15 18:46:00 -0300   1.0               NaN
# 1145106  2024-08-15 18:47:00 -0300   1.0               NaN
# 1145107  2024-08-15 18:48:00 -0300   1.0               NaN
# 1145108  2024-08-15 18:49:00 -0300   1.0               NaN
#
#                                                     device  ...  \
# 1137791  <<HKDevice: 0x3015746e0>, name:Apple Watch, ma...  ...
# 1137792  <<HKDevice: 0x3015746e0>, name:Apple Watch, ma...  ...
# 1137793  <<HKDevice: 0x3015746e0>, name:Apple Watch, ma...  ...
# 1137794  <<HKDevice: 0x3015746e0>, name:Apple Watch, ma...  ...
# 1137795  <<HKDevice: 0x3015746e0>, name:Apple Watch, ma...  ...
# ...                                                    ...  ...
# 1145104  <<HKDevice: 0x3015748c0>, name:Apple Watch, ma...  ...
# 1145105  <<HKDevice: 0x3015748c0>, name:Apple Watch, ma...  ...
# 1145106  <<HKDevice: 0x3015748c0>, name:Apple Watch, ma...  ...
# 1145107  <<HKDevice: 0x3015748c0>, name:Apple Watch, ma...  ...
# 1145108  <<HKDevice: 0x3015748c0>, name:Apple Watch, ma...  ...
#
#          HKMetadataKeyHeartRateRecoveryActivityDuration  \
# 1137791                                             NaN
# 1137792                                             NaN
# 1137793                                             NaN
# 1137794                                             NaN
# 1137795                                             NaN
# ...                                                 ...
# 1145104                                             NaN
# 1145105                                             NaN
# 1145106                                             NaN
# 1145107                                             NaN
# 1145108                                             NaN
#
#         HKMetadataKeyHeartRateRecoveryTestType  \
# 1137791                                    NaN
# 1137792                                    NaN
# 1137793                                    NaN
# 1137794                                    NaN
# 1137795                                    NaN
# ...                                        ...
# 1145104                                    NaN
# 1145105                                    NaN
# 1145106                                    NaN
# 1145107                                    NaN
# 1145108                                    NaN
#
#          HKMetadataKeyHeartRateRecoveryMaxObservedRecoveryHeartRate  \
# 1137791                                                NaN
# 1137792                                                NaN
# 1137793                                                NaN
# 1137794                                                NaN
# 1137795                                                NaN
# ...                                                    ...
# 1145104                                                NaN
# 1145105                                                NaN
# 1145106                                                NaN
# 1145107                                                NaN
# 1145108                                                NaN
#
#         HKMetadataKeyHeartRateRecoveryActivityType  \
# 1137791                                        NaN
# 1137792                                        NaN
# 1137793                                        NaN
# 1137794                                        NaN
# 1137795                                        NaN
# ...                                            ...
# 1145104                                        NaN
# 1145105                                        NaN
# 1145106                                        NaN
# 1145107                                        NaN
# 1145108                                        NaN
#
#          HKMetadataKeyMaximumLightIntensity HKActivityType  \
# 1137791                                 NaN            NaN
# 1137792                                 NaN            NaN
# 1137793                                 NaN            NaN
# 1137794                                 NaN            NaN
# 1137795                                 NaN            NaN
# ...                                     ...            ...
# 1145104                                 NaN            NaN
# 1145105                                 NaN            NaN
# 1145106                                 NaN            NaN
# 1145107                                 NaN            NaN
# 1145108                                 NaN            NaN
#
#          HKPhysicalEffortEstimationType  HKIndoorWorkout  HKTimeZone  \
# 1137791                             NaN              NaN         NaN
# 1137792                             NaN              NaN         NaN
# 1137793                             NaN              NaN         NaN
# 1137794                             NaN              NaN         NaN
# 1137795                             NaN              NaN         NaN
# ...                                 ...              ...         ...
# 1145104                             NaN              NaN         NaN
# 1145105                             NaN              NaN         NaN
# 1145106                             NaN              NaN         NaN
# 1145107                             NaN              NaN         NaN
# 1145108                             NaN              NaN         NaN
#
#          HKMetadataKeyAudioExposureLevel
# 1137791                              NaN
# 1137792                              NaN
# 1137793                              NaN
# 1137794                              NaN
# 1137795                              NaN
# ...                                  ...
# 1145104                              NaN
# 1145105                              NaN
# 1145106                              NaN
# 1145107                              NaN
# 1145108                              NaN
#
# [7278 rows x 31 columns]
# AppleExerciseTime    7278
# Name: type, dtype: int64
# Apple Watch de Edson    7278
# Name: sourceName, dtype: int64
# 10.5    5899
# 10.4    1379
# Name: sourceVersion, dtype: int64
# min    7278
# Name: unit, dtype: int64
# 2024-05-08 10:05:50 -0300    4
# 2024-04-28 11:45:26 -0300    3
# 2024-04-28 15:15:03 -0300    3
# 2024-06-23 17:17:26 -0300    3
# 2024-06-24 17:45:24 -0300    3
#                             ..
# 2024-06-10 19:24:43 -0300    1
# 2024-06-10 19:23:42 -0300    1
# 2024-06-10 19:22:41 -0300    1
# 2024-06-10 19:21:39 -0300    1
# 2024-08-15 18:49:52 -0300    1
# Name: creationDate, Length: 7195, dtype: int64
# 2024-04-28 08:51:00 -0300    1
# 2024-07-14 10:02:00 -0300    1
# 2024-07-15 18:16:00 -0300    1
# 2024-07-15 18:15:00 -0300    1
# 2024-07-15 18:14:00 -0300    1
#                             ..
# 2024-06-10 18:47:00 -0300    1
# 2024-06-10 18:46:00 -0300    1
# 2024-06-10 18:45:00 -0300    1
# 2024-06-10 18:44:00 -0300    1
# 2024-08-15 18:48:00 -0300    1
# Name: startDate, Length: 7278, dtype: int64
# 2024-04-28 08:52:00 -0300    1
# 2024-07-14 10:03:00 -0300    1
# 2024-07-15 18:17:00 -0300    1
# 2024-07-15 18:16:00 -0300    1
# 2024-07-15 18:15:00 -0300    1
#                             ..
# 2024-06-10 18:48:00 -0300    1
# 2024-06-10 18:47:00 -0300    1
# 2024-06-10 18:46:00 -0300    1
# 2024-06-10 18:45:00 -0300    1
# 2024-08-15 18:49:00 -0300    1
# Name: endDate, Length: 7278, dtype: int64
# 1.0    7278
# Name: value, dtype: int64
# Series([], Name: HKWasUserEntered, dtype: int64)
# <<HKDevice: 0x30163c550>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,14, software:10.5>    1200
# <<HKDevice: 0x30163d6d0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,14, software:10.5>     800
# <<HKDevice: 0x30163dae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,14, software:10.5>     800
# <<HKDevice: 0x301574690>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,14, software:10.5>     621
# <<HKDevice: 0x3015746e0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,14, software:10.4>     400
# <<HKDevice: 0x30163dae0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,14, software:10.4>     400
# <<HKDevice: 0x30163d6d0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,14, software:10.4>     400
# <<HKDevice: 0x3015754a0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,14, software:10.5>     400
# <<HKDevice: 0x301574780>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,14, software:10.5>     400
# <<HKDevice: 0x301574910>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,14, software:10.5>     400
# <<HKDevice: 0x301574a00>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,14, software:10.5>     400
# <<HKDevice: 0x301676030>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,14, software:10.5>     400
# <<HKDevice: 0x3015196d0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,14, software:10.5>     400
# <<HKDevice: 0x301574a00>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,14, software:10.4>     179
# <<HKDevice: 0x3015748c0>, name:Apple Watch, manufacturer:Apple Inc., model:Watch, hardware:Watch6,14, software:10.5>      78
# Name: device, dtype: int64
# Series([], Name: HKMetadataKeyHeartRateMotionContext, dtype: int64)
# Series([], Name: HKMetadataKeyBarometricPressure, dtype: int64)
# Series([], Name: HKMetadataKeySyncVersion, dtype: int64)
# Series([], Name: HKMetadataKeySyncIdentifier, dtype: int64)
# Series([], Name: HKVO2MaxTestType, dtype: int64)
# Series([], Name: HKDateOfEarliestDataUsedForEstimate, dtype: int64)
# Series([], Name: HKMetadataKeyAppleDeviceCalibrated, dtype: int64)
# Series([], Name: HKMetadataKeyDevicePlacementSide, dtype: int64)
# Series([], Name: HKAlgorithmVersion, dtype: int64)
# Series([], Name: HKMetadataKeyUserMotionContext, dtype: int64)
# Series([], Name: HKMetadataKeySessionEstimate, dtype: int64)
# Series([], Name: HKMetadataKeyHeartRateRecoveryActivityDuration, dtype: int64)
# Series([], Name: HKMetadataKeyHeartRateRecoveryTestType, dtype: int64)
# Series([], Name: HKMetadataKeyHeartRateRecoveryMaxObservedRecoveryHeartRate, dtype: int64)
# Series([], Name: HKMetadataKeyHeartRateRecoveryActivityType, dtype: int64)
# Series([], Name: HKMetadataKeyMaximumLightIntensity, dtype: int64)
# Series([], Name: HKActivityType, dtype: int64)
# Series([], Name: HKPhysicalEffortEstimationType, dtype: int64)
# Series([], Name: HKIndoorWorkout, dtype: int64)
# Series([], Name: HKTimeZone, dtype: int64)
# Series([], Name: HKMetadataKeyAudioExposureLevel, dtype: int64)
# Index(['type', 'sourceName', 'sourceVersion', 'unit', 'creationDate',
#        'startDate', 'endDate', 'value', 'HKWasUserEntered', 'device',
#        'HKMetadataKeyHeartRateMotionContext',
#        'HKMetadataKeyBarometricPressure', 'HKMetadataKeySyncVersion',
#        'HKMetadataKeySyncIdentifier', 'HKVO2MaxTestType',
#        'HKDateOfEarliestDataUsedForEstimate',
#        'HKMetadataKeyAppleDeviceCalibrated',
#        'HKMetadataKeyDevicePlacementSide', 'HKAlgorithmVersion',
#        'HKMetadataKeyUserMotionContext', 'HKMetadataKeySessionEstimate',
#        'HKMetadataKeyHeartRateRecoveryActivityDuration',
#        'HKMetadataKeyHeartRateRecoveryTestType',
#        'HKMetadataKeyHeartRateRecoveryMaxObservedRecoveryHeartRate',
#        'HKMetadataKeyHeartRateRecoveryActivityType',
#        'HKMetadataKeyMaximumLightIntensity', 'HKActivityType',
#        'HKPhysicalEffortEstimationType', 'HKIndoorWorkout', 'HKTimeZone',
#        'HKMetadataKeyAudioExposureLevel'],
#       dtype='object')

# %%
running_speed = data[data['type'] == "RunningSpeed"]
display(running_speed)
# Out:
#                  type            sourceName sourceVersion   unit  \
# 1254109  RunningSpeed  Apple Watch de Edson          10.4  km/hr
# 1254110  RunningSpeed  Apple Watch de Edson          10.4  km/hr
# 1254111  RunningSpeed  Apple Watch de Edson          10.4  km/hr
# 1254112  RunningSpeed  Apple Watch de Edson          10.4  km/hr
# 1254113  RunningSpeed  Apple Watch de Edson          10.4  km/hr
# ...               ...                   ...           ...    ...
# 1267367  RunningSpeed  Apple Watch de Edson          10.5  km/hr
# 1267368  RunningSpeed  Apple Watch de Edson          10.5  km/hr
# 1267369  RunningSpeed  Apple Watch de Edson          10.5  km/hr
# 1267370  RunningSpeed  Apple Watch de Edson          10.5  km/hr
# 1267371  RunningSpeed  Apple Watch de Edson          10.5  km/hr
#
#                       creationDate                  startDate  \
# 1254109  2024-05-04 16:40:23 -0300  2024-05-04 16:40:21 -0300
# 1254110  2024-05-04 16:40:26 -0300  2024-05-04 16:40:23 -0300
# 1254111  2024-05-04 16:40:28 -0300  2024-05-04 16:40:26 -0300
# 1254112  2024-05-04 16:40:31 -0300  2024-05-04 16:40:28 -0300
# 1254113  2024-05-04 16:40:34 -0300  2024-05-04 16:40:31 -0300
# ...                            ...                        ...
# 1267367  2024-08-15 17:14:23 -0300  2024-08-15 17:14:21 -0300
# 1267368  2024-08-15 17:14:26 -0300  2024-08-15 17:14:23 -0300
# 1267369  2024-08-15 17:14:29 -0300  2024-08-15 17:14:26 -0300
# 1267370  2024-08-15 17:14:31 -0300  2024-08-15 17:14:28 -0300
# 1267371  2024-08-15 17:14:34 -0300  2024-08-15 17:14:31 -0300
#
#                            endDate    value  HKWasUserEntered  \
# 1254109  2024-05-04 16:40:21 -0300  6.01803               NaN
# 1254110  2024-05-04 16:40:23 -0300  8.25646               NaN
# 1254111  2024-05-04 16:40:26 -0300  9.50175               NaN
# 1254112  2024-05-04 16:40:28 -0300    10.47               NaN
# 1254113  2024-05-04 16:40:31 -0300  11.9789               NaN
# ...                            ...      ...               ...
# 1267367  2024-08-15 17:14:21 -0300  9.33446               NaN
# 1267368  2024-08-15 17:14:23 -0300  9.33873               NaN
# 1267369  2024-08-15 17:14:26 -0300  9.46678               NaN
# 1267370  2024-08-15 17:14:28 -0300  9.32789               NaN
# 1267371  2024-08-15 17:14:31 -0300  9.46234               NaN
#
#                                                     device  ...  \
# 1254109  <<HKDevice: 0x30163e5d0>, name:Apple Watch, ma...  ...
# 1254110  <<HKDevice: 0x30163e5d0>, name:Apple Watch, ma...  ...
# 1254111  <<HKDevice: 0x30163e5d0>, name:Apple Watch, ma...  ...
# 1254112  <<HKDevice: 0x30163e5d0>, name:Apple Watch, ma...  ...
# 1254113  <<HKDevice: 0x30163e5d0>, name:Apple Watch, ma...  ...
# ...                                                    ...  ...
# 1267367  <<HKDevice: 0x30163d6d0>, name:Apple Watch, ma...  ...
# 1267368  <<HKDevice: 0x30163d6d0>, name:Apple Watch, ma...  ...
# 1267369  <<HKDevice: 0x30163d6d0>, name:Apple Watch, ma...  ...
# 1267370  <<HKDevice: 0x30163d6d0>, name:Apple Watch, ma...  ...
# 1267371  <<HKDevice: 0x30163d6d0>, name:Apple Watch, ma...  ...
#
#          HKMetadataKeyHeartRateRecoveryActivityDuration  \
# 1254109                                             NaN
# 1254110                                             NaN
# 1254111                                             NaN
# 1254112                                             NaN
# 1254113                                             NaN
# ...                                                 ...
# 1267367                                             NaN
# 1267368                                             NaN
# 1267369                                             NaN
# 1267370                                             NaN
# 1267371                                             NaN
#
#         HKMetadataKeyHeartRateRecoveryTestType  \
# 1254109                                    NaN
# 1254110                                    NaN
# 1254111                                    NaN
# 1254112                                    NaN
# 1254113                                    NaN
# ...                                        ...
# 1267367                                    NaN
# 1267368                                    NaN
# 1267369                                    NaN
# 1267370                                    NaN
# 1267371                                    NaN
#
#          HKMetadataKeyHeartRateRecoveryMaxObservedRecoveryHeartRate  \
# 1254109                                                NaN
# 1254110                                                NaN
# 1254111                                                NaN
# 1254112                                                NaN
# 1254113                                                NaN
# ...                                                    ...
# 1267367                                                NaN
# 1267368                                                NaN
# 1267369                                                NaN
# 1267370                                                NaN
# 1267371                                                NaN
#
#         HKMetadataKeyHeartRateRecoveryActivityType  \
# 1254109                                        NaN
# 1254110                                        NaN
# 1254111                                        NaN
# 1254112                                        NaN
# 1254113                                        NaN
# ...                                            ...
# 1267367                                        NaN
# 1267368                                        NaN
# 1267369                                        NaN
# 1267370                                        NaN
# 1267371                                        NaN
#
#          HKMetadataKeyMaximumLightIntensity HKActivityType  \
# 1254109                                 NaN            NaN
# 1254110                                 NaN            NaN
# 1254111                                 NaN            NaN
# 1254112                                 NaN            NaN
# 1254113                                 NaN            NaN
# ...                                     ...            ...
# 1267367                                 NaN            NaN
# 1267368                                 NaN            NaN
# 1267369                                 NaN            NaN
# 1267370                                 NaN            NaN
# 1267371                                 NaN            NaN
#
#          HKPhysicalEffortEstimationType  HKIndoorWorkout  HKTimeZone  \
# 1254109                             NaN              NaN         NaN
# 1254110                             NaN              NaN         NaN
# 1254111                             NaN              NaN         NaN
# 1254112                             NaN              NaN         NaN
# 1254113                             NaN              NaN         NaN
# ...                                 ...              ...         ...
# 1267367                             NaN              NaN         NaN
# 1267368                             NaN              NaN         NaN
# 1267369                             NaN              NaN         NaN
# 1267370                             NaN              NaN         NaN
# 1267371                             NaN              NaN         NaN
#
#          HKMetadataKeyAudioExposureLevel
# 1254109                              NaN
# 1254110                              NaN
# 1254111                              NaN
# 1254112                              NaN
# 1254113                              NaN
# ...                                  ...
# 1267367                              NaN
# 1267368                              NaN
# 1267369                              NaN
# 1267370                              NaN
# 1267371                              NaN
#
# [13263 rows x 31 columns]
